# %%
# from main import get_default_config, train_glow
# from data import setup_data
# %load_ext autoreload
# %autoreload 1

# %aimport main
# %aimport train
# %aimport data

# %%
config_dict = {
        'image_path': "../../datasets/celeba/img_align_celeba",
        'train_split': 0.6,
        'image_size': 64,
        'num_channels': 3,
        'num_bits': 5,
        'batch_size': 32,
        'K': 16,
        'L': 3,
        'nn_width': 512, 
        'learn_top_prior': True,
        'sampling_temperature': 0.7,
        'init_lr': 1e-3,
        'num_epochs': 13,
        'num_warmup_epochs': 1,
        'num_sample_epochs': 0.2, # Fractional epochs for sampling because one epoch is quite long 
        'num_save_epochs': 5,
    }

# %%
train_ds, val_ds = data.setup_data(config_dict,show_grid=True)
# Out:
# 202599 training images
# 6331 training steps per epoch

# %%
model, params = train.train_glow(train_ds, val_ds=val_ds, **config_dict)
# Out:
# Start training...
# Available jax devices: [GpuDevice(id=0, process_index=0), GpuDevice(id=1, process_index=0), GpuDevice(id=2, process_index=0), GpuDevice(id=3, process_index=0)]
#
# [Epoch 1/13][00h 34mn] train_bits/dims = 1.571, val_bits/dims = 1.266
# [Epoch 2/13][01h 06mn] train_bits/dims = 1.506, val_bits/dims = 1.225
# [Epoch 3/13][Batch 1094/6331] loss = 1.47418, (log(p(z)) = -1.74284, logdet = 5.26867)
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [Epoch 4/13][02h 10mn] train_bits/dims = 1.474, val_bits/dims = 1.240
# [Epoch 5/13][02h 42mn] train_bits/dims = 1.500, val_bits/dims = 1.297
# [Epoch 6/13][03h 14mn] train_bits/dims = 1.522, val_bits/dims = 1.214
# [Epoch 7/13][03h 46mn] train_bits/dims = 1.472, val_bits/dims = 1.191
# [Epoch 8/13][04h 18mn] train_bits/dims = 1.504, val_bits/dims = 1.304
# [Epoch 9/13][04h 50mn] train_bits/dims = 1.515, val_bits/dims = 1.218
# [Epoch 10/13][05h 22mn] train_bits/dims = 1.457, val_bits/dims = 1.081
# [Epoch 11/13][05h 53mn] train_bits/dims = 1.516, val_bits/dims = 1.201
# [Epoch 12/13][06h 25mn] train_bits/dims = 1.489, val_bits/dims = 1.256
# [Epoch 13/13][06h 57mn] train_bits/dims = 1.541, val_bits/dims = 1.254
